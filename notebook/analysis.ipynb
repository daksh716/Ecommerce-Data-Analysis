# %%
   print("Hello, my E-Commerce project has started!")
# Out:
# Hello, my E-Commerce project has started!

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
print("all libraries imported succesfully")
# Out:
# all libraries imported succesfully

# %%
   import os
   print(os.getcwd())
   print(os.listdir())
   print(os.listdir("data"))
# Out:
# c:\Users\DELL\project\Ecommerce-Data-Analysis
# ['analysis.ipynb', 'data']
# ['data.csv']

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\DELL\project\Ecommerce-Data-Analysis
# ['analysis.ipynb']

# %%
import pandas as pd

df = pd.read_csv("../data/data.csv", encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
print(df["Region"].unique())
print(df["Segment"].unique())
print(df["Ship Mode"].unique())
# Out:
# ['South' 'West' 'Central' 'East']
# ['Consumer' 'Corporate' 'Home Office']
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.boxplot(x=df["Sales"])
plt.title("Box Plot of Sales")
plt.show()

# %%
Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)
IQR = Q3 - Q1

upper_limit = Q3 + 1.5 * IQR

outliers = df[df["Sales"] > upper_limit]
print("Number of outlier rows:", outliers.shape[0])
outliers[["Order ID", "Category", "Sub-Category", "Sales", "Profit"]].head()
# Out:
# Number of outlier rows: 1167
#           Order ID    Category Sub-Category      Sales    Profit
# 1   CA-2016-152156   Furniture       Chairs   731.9400  219.5820
# 3   US-2015-108966   Furniture       Tables   957.5775 -383.0310
# 7   CA-2014-115812  Technology       Phones   907.1520   90.7152
# 10  CA-2014-115812   Furniture       Tables  1706.1840   85.3092
# 11  CA-2014-115812  Technology       Phones   911.4240   68.3568

# %%
total_sales = df["Sales"].sum()
print("Total Sales: $", round(total_sales, 2))
# Out:
# Total Sales: $ 2297200.86

# %%
average_sales = df["Sales"].mean()
print("Average Sale per Order:", round(average_sales, 2))
# Out:
# Average Sale per Order: 229.86

# %%
median_sales = df["Sales"].median()
print("Median Sale per Order:", round(median_sales, 2))
# Out:
# Median Sale per Order: 54.49

# %%
df["Order Month"] = df["Order Date"].dt.to_period("M")

monthly_sales = df.groupby("Order Month")["Sales"].sum()
print(monthly_sales)
# Out:
# Order Month
# 2014-01     14236.8950
# 2014-02      4519.8920
# 2014-03     55691.0090
# 2014-04     28295.3450
# 2014-05     23648.2870
# 2014-06     34595.1276
# 2014-07     33946.3930
# 2014-08     27909.4685
# 2014-09     81777.3508
# 2014-10     31453.3930
# 2014-11     78628.7167
# 2014-12     69545.6205
# 2015-01     18174.0756
# 2015-02     11951.4110
# 2015-03     38726.2520
# 2015-04     34195.2085
# 2015-05     30131.6865
# 2015-06     24797.2920
# 2015-07     28765.3250
# 2015-08     36898.3322
# 2015-09     64595.9180
# 2015-10     31404.9235
# 2015-11     75972.5635
# 2015-12     74919.5212
# 2016-01     18542.4910
# 2016-02     22978.8150
# 2016-03     51715.8750
# 2016-04     38750.0390
# 2016-05     56987.7280
# 2016-06     40344.5340
# 2016-07     39261.9630
# 2016-08     31115.3743
# 2016-09     73410.0249
# 2016-10     59687.7450
# 2016-11     79411.9658
# 2016-12     96999.0430
# 2017-01     43971.3740
# 2017-02     20301.1334
# 2017-03     58872.3528
# ...

# %%
plt.figure(figsize=(14, 5))
monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend (2014-2017)")
plt.xlabel("Month")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 5))
category_sales.plot(kind="bar", color=["#4C72B0", "#55A868", "#C44E52"])
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=0)
plt.show()

# %%
total_profit = df["Profit"].sum()
print("Total Profit: $", round(total_profit, 2))
# Out:
# Total Profit: $ 286397.02

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
print(category_profit)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
subcat_profit = df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)
print(subcat_profit)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10, 6))
colors = ["red" if val < 0 else "green" for val in subcat_profit.values]
subcat_profit.plot(kind="barh", color=colors)
plt.title("Profit by Sub-Category")
plt.xlabel("Total Profit ($)")
plt.ylabel("Sub-Category")
plt.axvline(0, color="black", linewidth=0.8)
plt.show()

# %%
region_profit = df.groupby("Region")["Profit"].sum().sort_values(ascending=False)
print(region_profit)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
top_products_sales = df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
print(top_products_sales)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
product_summary = df.groupby("Product Name")[["Sales", "Profit"]].sum()
high_sales_low_profit = product_summary[
    (product_summary["Sales"] > product_summary["Sales"].quantile(0.75)) &
    (product_summary["Profit"] < 0)
].sort_values("Profit")

print(high_sales_low_profit.head(10))
# Out:
#                                                         Sales     Profit
# Product Name
# Cubify CubeX 3D Printer Double Head Print           11099.963 -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer           16829.901 -4589.9730
# Cubify CubeX 3D Printer Triple Head Print            7999.980 -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Table...   9917.640 -2876.1156
# Bush Advantage Collection Racetrack Conference ...   9544.725 -1934.3976
# GBC DocuBind P400 Electric Binding System           17965.068 -1878.1662
# Cisco TelePresence System EX90 Videoconferencin...  22638.480 -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener  16656.200 -1299.1836
# Balt Solid Wood Round Tables                         6518.754 -1201.0581
# BoxOffice By Design Rectangular and Half-Moon M...   1706.250 -1148.4375

# %%
low_sales_high_profit = product_summary[
    (product_summary["Sales"] < product_summary["Sales"].quantile(0.25)) &
    (product_summary["Profit"] > 0)
].sort_values("Profit", ascending=False)

print(low_sales_high_profit.head(10))
# Out:
#                                                      Sales   Profit
# Product Name
# Xerox 219                                           97.200  46.6560
# Xerox 228                                           97.200  46.6560
# Xerox 1987                                          92.480  45.3152
# Xerox 1952                                          97.608  44.8200
# Avery 478                                           88.380  43.3062
# Adams Phone Message Book, Professional, 400 Mes...  94.928  43.1364
# Avery 481                                           91.168  43.1200
# Avery 495                                           97.020  42.5880
# Avery 480                                           89.250  42.4500
# Avery White Multi-Purpose Labels                    95.616  41.8320

# %%
unique_customers = df["Customer ID"].nunique()
print("Number of Unique Customers:", unique_customers)
# Out:
# Number of Unique Customers: 793

# %%
top_customers_sales = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)
print(top_customers_sales)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
top_customers_profit = df.groupby("Customer Name")["Profit"].sum().sort_values(ascending=False).head(10)
print(top_customers_profit)
# Out:
# Customer Name
# Tamara Chand            8981.3239
# Raymond Buch            6976.0959
# Sanjit Chand            5757.4119
# Hunter Lopez            5622.4292
# Adrian Barton           5444.8055
# Tom Ashbrook            4703.7883
# Christopher Martinez    3899.8904
# Keith Dawkins           3038.6254
# Andy Reiter             2884.6208
# Daniel Raglin           2869.0760
# Name: Profit, dtype: float64

# %%
avg_spend_per_customer = df.groupby("Customer Name")["Sales"].sum().mean()
print("Average Total Spend per Customer:", round(avg_spend_per_customer, 2))
# Out:
# Average Total Spend per Customer: 2896.85

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
region_orders = df.groupby("Region")["Order ID"].nunique().sort_values(ascending=False)

print("Sales by Region:\n", region_sales)
print("\nOrders by Region:\n", region_orders)
# Out:
# Sales by Region:
#  Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64
#
# Orders by Region:
#  Region
# West       1611
# East       1401
# Central    1175
# South       822
# Name: Order ID, dtype: int64

# %%
print(df["Discount"].value_counts().sort_index())
# Out:
# Discount
# 0.00    4798
# 0.10      94
# 0.15      52
# 0.20    3657
# 0.30     227
# 0.32      27
# 0.40     206
# 0.45      11
# 0.50      66
# 0.60     138
# 0.70     418
# 0.80     300
# Name: count, dtype: int64

# %%
correlation = df["Discount"].corr(df["Profit"])
print("Correlation between Discount and Profit:", round(correlation, 3))
# Out:
# Correlation between Discount and Profit: -0.219

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Discount"], y=df["Profit"], alpha=0.4)
plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.axhline(0, color="red", linestyle="--")
plt.show()

# %%
profit_by_discount = df.groupby("Discount")["Profit"].mean().sort_index()
print(profit_by_discount)
# Out:
# Discount
# 0.00     66.900292
# 0.10     96.055074
# 0.15     27.288298
# 0.20     24.702572
# 0.30    -45.679636
# 0.32    -88.560656
# 0.40   -111.927429
# 0.45   -226.646464
# 0.50   -310.703456
# 0.60    -43.077212
# 0.70    -95.874060
# 0.80   -101.796797
# Name: Profit, dtype: float64

# %%
avg_discount_by_subcat = df.groupby("Sub-Category")["Discount"].mean().sort_values(ascending=False)
print(avg_discount_by_subcat)
# Out:
# Sub-Category
# Binders        0.372292
# Machines       0.306087
# Tables         0.261285
# Bookcases      0.211140
# Chairs         0.170178
# Appliances     0.166524
# Copiers        0.161765
# Phones         0.154556
# Furnishings    0.138349
# Fasteners      0.082028
# Envelopes      0.080315
# Accessories    0.078452
# Supplies       0.076842
# Paper          0.074891
# Art            0.074874
# Storage        0.074704
# Labels         0.068681
# Name: Discount, dtype: float64

# %%
print("Mode of Discount:", df["Discount"].mode()[0])
# Out:
# Mode of Discount: 0.0

# %%
sales_range = df["Sales"].max() - df["Sales"].min()
print("Range of Sales:", round(sales_range, 2))
# Out:
# Range of Sales: 22638.04

# %%
sales_variance = df["Sales"].var()
sales_std = df["Sales"].std()
print("Variance of Sales:", round(sales_variance, 2))
print("Standard Deviation of Sales:", round(sales_std, 2))
# Out:
# Variance of Sales: 388434.46
# Standard Deviation of Sales: 623.25

# %%
Q1 = df["Sales"].quantile(0.25)
Q2 = df["Sales"].quantile(0.50)
Q3 = df["Sales"].quantile(0.75)
IQR = Q3 - Q1

print("Q1 (25th percentile):", Q1)
print("Q2 (Median/50th percentile):", Q2)
print("Q3 (75th percentile):", Q3)
print("IQR:", round(IQR, 2))
# Out:
# Q1 (25th percentile): 17.28
# Q2 (Median/50th percentile): 54.489999999999995
# Q3 (75th percentile): 209.94
# IQR: 192.66

# %%
correlation_matrix = df[["Sales", "Quantity", "Discount", "Profit"]].corr()
print(correlation_matrix)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap: Sales, Quantity, Discount, Profit")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["Sales"], bins=50, kde=True)
plt.title("Distribution of Sales")
plt.xlabel("Sales ($)")
plt.ylabel("Number of Orders")
plt.show()

# %%
plt.figure(figsize=(8, 5))
region_sales.plot(kind="bar", color="#4C72B0")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_customers_sales.sort_values().plot(kind="barh", color="#55A868")
plt.title("Top 10 Customers by Sales")
plt.xlabel("Total Sales ($)")
plt.ylabel("Customer Name")
plt.show()

# %%
import datetime as dt

snapshot_date = df["Order Date"].max() + dt.timedelta(days=1)

rfm = df.groupby("Customer Name").agg({
    "Order Date": lambda x: (snapshot_date - x.max()).days,
    "Order ID": "nunique",
    "Sales": "sum"
})

rfm.columns = ["Recency", "Frequency", "Monetary"]
print(rfm.head())
# Out:
#                  Recency  Frequency  Monetary
# Customer Name
# Aaron Bergman        416          3   886.156
# Aaron Hawkins         13          7  1744.700
# Aaron Smayling        89          7  3050.692
# Adam Bellavance       55          8  7755.620
# Adam Hart             35         10  3250.337

# %%
rfm["R_Score"] = pd.qcut(rfm["Recency"], 4, labels=[4, 3, 2, 1])
rfm["F_Score"] = pd.qcut(rfm["Frequency"].rank(method="first"), 4, labels=[1, 2, 3, 4])
rfm["M_Score"] = pd.qcut(rfm["Monetary"], 4, labels=[1, 2, 3, 4])

print(rfm.head())
# Out:
#                  Recency  Frequency  Monetary R_Score F_Score M_Score
# Customer Name
# Aaron Bergman        416          3   886.156       1       1       1
# Aaron Hawkins         13          7  1744.700       4       3       2
# Aaron Smayling        89          7  3050.692       2       3       3
# Adam Bellavance       55          8  7755.620       3       3       4
# Adam Hart             35         10  3250.337       3       4       3

# %%
rfm["RFM_Score"] = rfm["R_Score"].astype(str) + rfm["F_Score"].astype(str) + rfm["M_Score"].astype(str)

def segment_customer(row):
    if row["R_Score"] == 4 and row["F_Score"] == 4 and row["M_Score"] == 4:
        return "Champions"
    elif row["R_Score"] >= 3 and row["F_Score"] >= 3:
        return "Loyal Customers"
    elif row["R_Score"] <= 2 and row["F_Score"] >= 3:
        return "At Risk"
    elif row["R_Score"] == 1 and row["F_Score"] == 1:
        return "Lost"
    else:
        return "Needs Attention"

rfm["Segment"] = rfm.apply(segment_customer, axis=1)
print(rfm["Segment"].value_counts())
# Out:
# Segment
# Needs Attention    305
# Loyal Customers    204
# At Risk            158
# Lost                92
# Champions           34
# Name: count, dtype: int64
